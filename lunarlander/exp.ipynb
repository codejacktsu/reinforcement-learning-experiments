# %% [markdown]
# Sample Game

# %%
import gymnasium as gym


env = gym.make("LunarLander-v2", render_mode="human")

observation, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample()
    print(f"Action: {action}")
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()
        print("Environment reset")

env.close()

# %% [markdown]
# Action/Observation Space

# %%
env = gym.make("LunarLander-v2")
# create multiple environments
# env = make_vec_env("LunarLander-v2", n_envs=16)
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())  # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())  # Take a random action

# %% [markdown]
# Model

# %%
import gymnasium as gym
import time

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create environment
env = make_vec_env('LunarLander-v2')

# Instantiate the agent
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1,
    device='cpu')

# train
start_time = time.time()
model.learn(total_timesteps=int(2e6))
end_time = time.time()

# save model
model_name = "ppo-LunarLander-v2"
model.save(model_name)

# print training time
print(f"Training time: {end_time - start_time} seconds")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.5     |
# |    ep_rew_mean     | -178     |
# | time/              |          |
# |    fps             | 2633     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 87.2           |
# |    ep_rew_mean          | -168           |
# | time/                   |                |
# |    fps                  | 2387           |
# |    iterations           | 2              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 2048           |
# | train/                  |                |
# |    approx_kl            | 0.0019579632   |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.39          |
# |    explained_variance   | -0.00034320354 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.52e+03       |
# |    n_updates            | 4              |
# |    policy_gradient_loss | -0.0051        |
# |    value_loss           | 6.85e+03       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 88.9          |
# |    ep_rew_mean          | -157          |
# | time/                   |               |
# |    fps                  | 2309          |
# |    iterations           | 3             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00070005015 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.006517291  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.61e+03      |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.00255      |
# |    value_loss           | 4.98e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 89.4          |
# |    ep_rew_mean          | -153          |
# | time/                   |               |
# |    fps                  | 2283          |
# |    iterations           | 4             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0015298203  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0062499046 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.06e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.00401      |
# |    value_loss           | 3.29e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 89.5          |
# |    ep_rew_mean          | -149          |
# | time/                   |               |
# |    fps                  | 2274          |
# |    iterations           | 5             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.0013817681  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0020276308 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+03      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.00238      |
# |    value_loss           | 3.6e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 89.2          |
# |    ep_rew_mean          | -149          |
# | time/                   |               |
# |    fps                  | 2249          |
# |    iterations           | 6             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00016072596 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.015266776  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.21e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000801     |
# |    value_loss           | 2.84e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 89.3          |
# |    ep_rew_mean          | -147          |
# | time/                   |               |
# |    fps                  | 2240          |
# |    iterations           | 7             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.0011810833  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0103007555 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.38e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.00241      |
# |    value_loss           | 3.21e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.3         |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 2219         |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.00250985   |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0047661066 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+03     |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 2.51e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.2          |
# |    ep_rew_mean          | -149          |
# | time/                   |               |
# |    fps                  | 2208          |
# |    iterations           | 9             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.0013649086  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.0011223555 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.66e+03      |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.00255      |
# |    value_loss           | 3.33e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.5          |
# |    ep_rew_mean          | -146          |
# | time/                   |               |
# |    fps                  | 2199          |
# |    iterations           | 10            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0033156918  |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.0077517033 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.43e+03      |
# |    n_updates            | 36            |
# |    policy_gradient_loss | -0.00636      |
# |    value_loss           | 3.83e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.5          |
# |    ep_rew_mean          | -147          |
# | time/                   |               |
# |    fps                  | 2194          |
# |    iterations           | 11            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00032497768 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.026131988  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+03      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 3.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93.9          |
# |    ep_rew_mean          | -143          |
# | time/                   |               |
# |    fps                  | 2196          |
# |    iterations           | 12            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00029781146 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.019697785  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.24e+03      |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 2.69e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.2          |
# |    ep_rew_mean          | -141          |
# | time/                   |               |
# |    fps                  | 2192          |
# |    iterations           | 13            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 0.0037210514  |
# |    clip_fraction        | 0.00562       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0014690161 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 659           |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.00473      |
# |    value_loss           | 1.9e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.5         |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 2190         |
# |    iterations           | 14           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0024190203 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.002128005  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 972          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 2.52e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 99.2          |
# |    ep_rew_mean          | -145          |
# | time/                   |               |
# |    fps                  | 2181          |
# |    iterations           | 15            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 0.00060296734 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0006201267 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+03      |
# |    n_updates            | 56            |
# |    policy_gradient_loss | -0.00097      |
# |    value_loss           | 2.59e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 2179         |
# |    iterations           | 16           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0012515979 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0016546249 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 768          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -137          |
# | time/                   |               |
# |    fps                  | 2179          |
# |    iterations           | 17            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.0024288567  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.0018041134 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 745           |
# |    n_updates            | 64            |
# |    policy_gradient_loss | -0.00404      |
# |    value_loss           | 1.45e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 103           |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 2179          |
# |    iterations           | 18            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0006665395  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.0017248392 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 679           |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 1.7e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -133          |
# | time/                   |               |
# |    fps                  | 2175          |
# |    iterations           | 19            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00029759452 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -0.024450898  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.46e+03      |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.00062      |
# |    value_loss           | 2.68e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 105           |
# |    ep_rew_mean          | -134          |
# | time/                   |               |
# |    fps                  | 2171          |
# |    iterations           | 20            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00057955965 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -0.0006811619 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 973           |
# |    n_updates            | 76            |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 1.59e+03      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 105            |
# |    ep_rew_mean          | -132           |
# | time/                   |                |
# |    fps                  | 2167           |
# |    iterations           | 21             |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 21504          |
# | train/                  |                |
# |    approx_kl            | 0.0011658345   |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.3           |
# |    explained_variance   | -0.00018334389 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.3e+03        |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -0.00262       |
# |    value_loss           | 2.42e+03       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -133          |
# | time/                   |               |
# |    fps                  | 2163          |
# |    iterations           | 22            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.0039122785  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -0.0018738508 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 767           |
# |    n_updates            | 84            |
# |    policy_gradient_loss | -0.00423      |
# |    value_loss           | 2.07e+03      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 109            |
# |    ep_rew_mean          | -138           |
# | time/                   |                |
# |    fps                  | 2163           |
# |    iterations           | 23             |
# |    time_elapsed         | 10             |
# |    total_timesteps      | 23552          |
# | train/                  |                |
# |    approx_kl            | 0.006528977    |
# |    clip_fraction        | 0.02           |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.33          |
# |    explained_variance   | -0.00084221363 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 571            |
# |    n_updates            | 88             |
# |    policy_gradient_loss | -0.00652       |
# |    value_loss           | 1.26e+03       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -135         |
# | time/                   |              |
# |    fps                  | 2162         |
# |    iterations           | 24           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0008331638 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0005620718 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 3.03e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 111           |
# |    ep_rew_mean          | -136          |
# | time/                   |               |
# |    fps                  | 2162          |
# |    iterations           | 25            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 0.0020664597  |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | -0.0040796995 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 558           |
# |    n_updates            | 96            |
# |    policy_gradient_loss | -0.00396      |
# |    value_loss           | 1.04e+03      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 112            |
# |    ep_rew_mean          | -133           |
# | time/                   |                |
# |    fps                  | 2163           |
# |    iterations           | 26             |
# |    time_elapsed         | 12             |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | 0.005852191    |
# |    clip_fraction        | 0.0083         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.26          |
# |    explained_variance   | -0.00021767616 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.74e+03       |
# |    n_updates            | 100            |
# |    policy_gradient_loss | -0.00717       |
# |    value_loss           | 4.07e+03       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 112            |
# |    ep_rew_mean          | -132           |
# | time/                   |                |
# |    fps                  | 2165           |
# |    iterations           | 27             |
# |    time_elapsed         | 12             |
# |    total_timesteps      | 27648          |
# | train/                  |                |
# |    approx_kl            | 0.007747494    |
# |    clip_fraction        | 0.0166         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.32          |
# |    explained_variance   | -0.00058317184 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 405            |
# |    n_updates            | 104            |
# |    policy_gradient_loss | -0.00425       |
# |    value_loss           | 732            |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 113            |
# |    ep_rew_mean          | -134           |
# | time/                   |                |
# |    fps                  | 2165           |
# |    iterations           | 28             |
# |    time_elapsed         | 13             |
# |    total_timesteps      | 28672          |
# | train/                  |                |
# |    approx_kl            | 0.002442249    |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.33          |
# |    explained_variance   | -0.00023031235 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 378            |
# |    n_updates            | 108            |
# |    policy_gradient_loss | -0.00365       |
# |    value_loss           | 1.22e+03       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 112            |
# |    ep_rew_mean          | -128           |
# | time/                   |                |
# |    fps                  | 2168           |
# |    iterations           | 29             |
# |    time_elapsed         | 13             |
# |    total_timesteps      | 29696          |
# | train/                  |                |
# |    approx_kl            | 0.005668466    |
# |    clip_fraction        | 0.00415        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.33          |
# |    explained_variance   | -0.00064349174 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 441            |
# |    n_updates            | 112            |
# |    policy_gradient_loss | -0.00439       |
# |    value_loss           | 833            |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -126         |
# | time/                   |              |
# |    fps                  | 2166         |
# |    iterations           | 30           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.004758479  |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.003931403 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 219          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 500          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 116           |
# |    ep_rew_mean          | -120          |
# | time/                   |               |
# |    fps                  | 2167          |
# |    iterations           | 31            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 0.008850558   |
# |    clip_fraction        | 0.0581        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | -0.0073057413 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 586           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00451      |
# |    value_loss           | 750           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 115           |
# |    ep_rew_mean          | -115          |
# | time/                   |               |
# |    fps                  | 2170          |
# |    iterations           | 32            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.0032928186  |
# |    clip_fraction        | 0.00488       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -0.0003427267 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 176           |
# |    n_updates            | 124           |
# |    policy_gradient_loss | -0.00025      |
# |    value_loss           | 730           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 114           |
# |    ep_rew_mean          | -111          |
# | time/                   |               |
# |    fps                  | 2168          |
# |    iterations           | 33            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.014415199   |
# |    clip_fraction        | 0.0771        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -0.0004892349 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 182           |
# |    n_updates            | 128           |
# |    policy_gradient_loss | -0.0105       |
# |    value_loss           | 513           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 124          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 2122         |
# |    iterations           | 34           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0119949635 |
# |    clip_fraction        | 0.174        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.002974391  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 345          |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00945     |
# |    value_loss           | 606          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -98.6       |
# | time/                   |             |
# |    fps                  | 2122        |
# |    iterations           | 35          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009882564 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.10520828  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.3        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 149         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 126           |
# |    ep_rew_mean          | -97.8         |
# | time/                   |               |
# |    fps                  | 2120          |
# |    iterations           | 36            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.0044183154  |
# |    clip_fraction        | 0.0125        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.27         |
# |    explained_variance   | -0.0025236607 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 316           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.004        |
# |    value_loss           | 504           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 127           |
# |    ep_rew_mean          | -94.2         |
# | time/                   |               |
# |    fps                  | 2113          |
# |    iterations           | 37            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 37888         |
# | train/                  |               |
# |    approx_kl            | 0.0021880197  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | -0.0005838871 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 368           |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -0.00288      |
# |    value_loss           | 687           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | -90.2        |
# | time/                   |              |
# |    fps                  | 2085         |
# |    iterations           | 38           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0015944456 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0133731365 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 342          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 437          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | -91          |
# | time/                   |              |
# |    fps                  | 2084         |
# |    iterations           | 39           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0092070075 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.11440879   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 179          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 146           |
# |    ep_rew_mean          | -93.6         |
# | time/                   |               |
# |    fps                  | 2077          |
# |    iterations           | 40            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00032103056 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.15         |
# |    explained_variance   | -0.021183014  |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.05e+03      |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 2.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 150           |
# |    ep_rew_mean          | -90.7         |
# | time/                   |               |
# |    fps                  | 2077          |
# |    iterations           | 41            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 41984         |
# | train/                  |               |
# |    approx_kl            | 0.00022975507 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | -0.0006389618 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 487           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000631     |
# |    value_loss           | 1.02e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | -89.5        |
# | time/                   |              |
# |    fps                  | 2073         |
# |    iterations           | 42           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0059186313 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.002026081 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 247          |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00646     |
# |    value_loss           | 434          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 159           |
# |    ep_rew_mean          | -90.1         |
# | time/                   |               |
# |    fps                  | 2070          |
# |    iterations           | 43            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00091286097 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.16         |
# |    explained_variance   | -0.0007828474 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 227           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | -0.00188      |
# |    value_loss           | 548           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 159           |
# |    ep_rew_mean          | -88.4         |
# | time/                   |               |
# |    fps                  | 2039          |
# |    iterations           | 44            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.0005782108  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.16         |
# |    explained_variance   | -0.0007019043 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 607           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.00172      |
# |    value_loss           | 1.19e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -85.4        |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 45           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.006661351  |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0039230585 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 213          |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 436          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -80.6        |
# | time/                   |              |
# |    fps                  | 2032         |
# |    iterations           | 46           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0048049297 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.0026397705 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 148          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 362          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 175           |
# |    ep_rew_mean          | -78.5         |
# | time/                   |               |
# |    fps                  | 2032          |
# |    iterations           | 47            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.0008997839  |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | -0.0028582811 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 175           |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.00169      |
# |    value_loss           | 547           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | -72.6        |
# | time/                   |              |
# |    fps                  | 2034         |
# |    iterations           | 48           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033560502 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.004835844 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 208          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 478          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 177           |
# |    ep_rew_mean          | -71.2         |
# | time/                   |               |
# |    fps                  | 1998          |
# |    iterations           | 49            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00022613024 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | -0.0018094778 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 142           |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.000864     |
# |    value_loss           | 386           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | -69.3        |
# | time/                   |              |
# |    fps                  | 1964         |
# |    iterations           | 50           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024050476 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.022135675  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 188          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 366          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -66         |
# | time/                   |             |
# |    fps                  | 1958        |
# |    iterations           | 51          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.000869036 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.20200568  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 214         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 207           |
# |    ep_rew_mean          | -64.3         |
# | time/                   |               |
# |    fps                  | 1940          |
# |    iterations           | 52            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00021795678 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | -0.06186688   |
# |    learning_rate        | 0.0003        |
# |    loss                 | 118           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | -0.000506     |
# |    value_loss           | 334           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | -58          |
# | time/                   |              |
# |    fps                  | 1942         |
# |    iterations           | 53           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0007949011 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.021962762 |
# |    learning_rate        | 0.0003       |
# ...
# |    fps                  | 1514         |
# |    iterations           | 1937         |
# |    time_elapsed         | 1310         |
# |    total_timesteps      | 1983488      |
# | train/                  |              |
# |    approx_kl            | 0.0043146247 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.6922735    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 599          |
# |    n_updates            | 7744         |
# |    policy_gradient_loss | -0.000905    |
# |    value_loss           | 858          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 1513         |
# |    iterations           | 1938         |
# |    time_elapsed         | 1310         |
# |    total_timesteps      | 1984512      |
# | train/                  |              |
# |    approx_kl            | 0.0045109615 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.98945713   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92         |
# |    n_updates            | 7748         |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 13.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 239         |
# | time/                   |             |
# |    fps                  | 1513        |
# |    iterations           | 1939        |
# |    time_elapsed         | 1311        |
# |    total_timesteps      | 1985536     |
# | train/                  |             |
# |    approx_kl            | 0.006663298 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.99633396  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.635       |
# |    n_updates            | 7752        |
# |    policy_gradient_loss | -0.000673   |
# |    value_loss           | 5.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 1513         |
# |    iterations           | 1940         |
# |    time_elapsed         | 1312         |
# |    total_timesteps      | 1986560      |
# | train/                  |              |
# |    approx_kl            | 0.0010345422 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.8398294    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 7756         |
# |    policy_gradient_loss | -1.23e-06    |
# |    value_loss           | 371          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1941         |
# |    time_elapsed         | 1312         |
# |    total_timesteps      | 1987584      |
# | train/                  |              |
# |    approx_kl            | 0.0018278061 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.9669597    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22         |
# |    n_updates            | 7760         |
# |    policy_gradient_loss | -3.81e-05    |
# |    value_loss           | 23.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 332          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1942         |
# |    time_elapsed         | 1313         |
# |    total_timesteps      | 1988608      |
# | train/                  |              |
# |    approx_kl            | 0.0009141562 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | 0.9541529    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.89         |
# |    n_updates            | 7764         |
# |    policy_gradient_loss | 0.00142      |
# |    value_loss           | 34.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1943         |
# |    time_elapsed         | 1313         |
# |    total_timesteps      | 1989632      |
# | train/                  |              |
# |    approx_kl            | 0.0019602461 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.9580422    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13         |
# |    n_updates            | 7768         |
# |    policy_gradient_loss | 8.32e-05     |
# |    value_loss           | 29.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 1944        |
# |    time_elapsed         | 1314        |
# |    total_timesteps      | 1990656     |
# | train/                  |             |
# |    approx_kl            | 0.013982284 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.9732861   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.96        |
# |    n_updates            | 7772        |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1945         |
# |    time_elapsed         | 1315         |
# |    total_timesteps      | 1991680      |
# | train/                  |              |
# |    approx_kl            | 0.0032273668 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.6906148    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 170          |
# |    n_updates            | 7776         |
# |    policy_gradient_loss | 1.56e-05     |
# |    value_loss           | 965          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 1946        |
# |    time_elapsed         | 1315        |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.000305656 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.69513357  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 375         |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | -0.000825   |
# |    value_loss           | 918         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 322           |
# |    ep_rew_mean          | 246           |
# | time/                   |               |
# |    fps                  | 1514          |
# |    iterations           | 1947          |
# |    time_elapsed         | 1316          |
# |    total_timesteps      | 1993728       |
# | train/                  |               |
# |    approx_kl            | 0.00034130685 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.688        |
# |    explained_variance   | 0.8365245     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18.4          |
# |    n_updates            | 7784          |
# |    policy_gradient_loss | -5.89e-05     |
# |    value_loss           | 371           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 1948        |
# |    time_elapsed         | 1317        |
# |    total_timesteps      | 1994752     |
# | train/                  |             |
# |    approx_kl            | 0.003521212 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.9658909   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 7788        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 55.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1949         |
# |    time_elapsed         | 1317         |
# |    total_timesteps      | 1995776      |
# | train/                  |              |
# |    approx_kl            | 0.0040346268 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.9773195    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.03         |
# |    n_updates            | 7792         |
# |    policy_gradient_loss | -0.000947    |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1950         |
# |    time_elapsed         | 1318         |
# |    total_timesteps      | 1996800      |
# | train/                  |              |
# |    approx_kl            | 0.0019174163 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.9852165    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38         |
# |    n_updates            | 7796         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1951         |
# |    time_elapsed         | 1319         |
# |    total_timesteps      | 1997824      |
# | train/                  |              |
# |    approx_kl            | 0.0089700855 |
# |    clip_fraction        | 0.0735       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | 0.9881664    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34         |
# |    n_updates            | 7800         |
# |    policy_gradient_loss | -0.00606     |
# |    value_loss           | 12.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1952         |
# |    time_elapsed         | 1319         |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0065112966 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.9936254    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 7804         |
# |    policy_gradient_loss | -0.000718    |
# |    value_loss           | 7.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 1953        |
# |    time_elapsed         | 1320        |
# |    total_timesteps      | 1999872     |
# | train/                  |             |
# |    approx_kl            | 0.002968786 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.9517681   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.09        |
# |    n_updates            | 7808        |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 350          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 1954         |
# |    time_elapsed         | 1321         |
# |    total_timesteps      | 2000896      |
# | train/                  |              |
# |    approx_kl            | 0.0054138545 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.99206394   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63         |
# |    n_updates            | 7812         |
# |    policy_gradient_loss | 0.0022       |
# |    value_loss           | 10.2         |
# ------------------------------------------
# Training time: 1321.338583946228 seconds

# %% [markdown]
# Evaluate

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=261.88 +/- 18.90349049355859

# %% [markdown]
# Run Model

# %%
# Create a new environment for inference
env = gym.make("LunarLander-v2", render_mode="human")

# Reset the environment
obs, _ = env.reset()

# Run the model for a few episodes
for episode in range(5):
    episode_reward = 0
    done = False
    truncated = False
    
    while not (done or truncated):
        # Get the model's action
        action, _ = model.predict(obs, deterministic=True)
        
        # Take the action in the environment
        obs, reward, done, truncated, info = env.step(action)
        episode_reward += reward
    
    print(f"Episode {episode + 1} reward: {episode_reward}")
    
    # Reset the environment for the next episode
    obs, _ = env.reset()

# Close the environment
env.close()
# Out:
# Episode 1 reward: 295.45620828117933
# Episode 2 reward: 272.68909744880295
# Episode 3 reward: 249.66976016254492
# Episode 4 reward: 255.21906640260153
# Episode 5 reward: 266.1475719949203
